# %%
from pathlib import Path
import pandas as pd
import numpy as np
import os
import requests
from requests.auth import HTTPBasicAuth
import time
from google.colab import files

# %% [markdown]
# # 1. Configure API to EPO OPS
#
# Registro en OPS para la API: [OPS](https://www.epo.org/en/searching-for-patents/data/web-services/ops)
#
# Documentacion de la API: [OPS v1.3.19](https://link.epo.org/web/ops_v3.2_documentation_-_version_1.3.19_en.pdf)

# %%
client_id = 'i6AxJ1MYJ43N3SkC5CeRpujtzndUNHzRk72kulUA04n4wh8M'
client_secret = 'SFmlAli4KOlr1xPNygxRfgXNcfUmDzrtjpAkfv10Hkf6R1cEQsmXCBZjXV5zyhaQ'

# %%
# Authentication URL for the EPO API
auth_url = 'https://ops.epo.org/3.2/auth/accesstoken'

# Send a POST request to get the access token
auth_response = requests.post(auth_url,
                              auth=HTTPBasicAuth(client_id, client_secret),
                              headers={'Content-Type': 'application/x-www-form-urlencoded'},
                              data={'grant_type': 'client_credentials'})

# Parse the JSON response
auth_data = auth_response.json()

# Extract the access token from the response
access_token = auth_data['access_token']

# URL for the EPO API search endpoint
search_url = 'https://ops.epo.org/3.2/rest-services/published-data/search/biblio'

def get_patent_data(query_cql, start, end):
    """
    Function to retrieve patent data from the EPO API.

    :param query_cql: The CQL query string for searching patents
    :param start: The start index of the range of results to retrieve
    :param end: The end index of the range of results to retrieve
    :return: JSON response with patent data or None if there's an error
    """
    # Set up the headers for the API request
    headers = {
        'Authorization': f'Bearer {access_token}',
        'Accept': 'application/json',
        'Range': f'{start}-{end}'  # Specify the range of results to retrieve
    }

    # Set up the query parameters
    params = {
        'q': query_cql
    }

    # Send a GET request to the EPO API
    response = requests.get(search_url, headers=headers, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        return response.json()
    else:
        print(f'Error: {response.status_code} - {response.text}')
        return None

# Example CQL query to search for patents in the A61K IPC class
query_cql = 'ipc=/low A61K'

# Maximum number of results allowed per request by the API
batch_size = 100

data = get_patent_data(query_cql, start=1, end=3)

data
# Out:
# {'ops:world-patent-data': {'@xmlns': {'ops': 'http://ops.epo.org',
#    '$': 'http://www.epo.org/exchange',
#    'xlink': 'http://www.w3.org/1999/xlink'},
#   'ops:biblio-search': {'@total-result-count': '10000',
#    'ops:query': {'$': 'ipc =/low A61K', '@syntax': 'CQL'},
#    'ops:range': {'@begin': '1', '@end': '3'},
#    'ops:search-result': {'exchange-documents': [{'exchange-document': {'@system': 'ops.epo.org',
#        '@family-id': '89897625',
#        '@country': 'JP',
#        '@doc-number': '2024120161',
#        '@kind': 'A',
#        'bibliographic-data': {'publication-reference': {'document-id': [{'@document-id-type': 'docdb',
#            'country': {'$': 'JP'},
#            'doc-number': {'$': '2024120161'},
#            'kind': {'$': 'A'},
#            'date': {'$': '20240904'}},
#           {'@document-id-type': 'epodoc',
#            'doc-number': {'$': 'JP2024120161'},
#            'date': {'$': '20240904'}}]},
#         'classifications-ipcr': {'classification-ipcr': [{'@sequence': '1',
#            'text': {'$': 'A61K  31/   565            A I'}},
#           {'@sequence': '2', 'text': {'$': 'A61K  31/   585            A I'}},
#           {'@sequence': '3', 'text': {'$': 'A61P   5/    30            A I'}},
#           {'@sequence': '4', 'text': {'$': 'A61P   5/    34            A I'}},
#           {'@sequence': '5',
#            'text': {'$': 'A61P  43/    00            A I'}}]},
#         'patent-classifications': {'patent-classification': [{'@sequence': '1',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '31'},
#            'subgroup': {'$': '565'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'EP'}},
#           {'@sequence': '2',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '31'},
#            'subgroup': {'$': '585'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'EP'}},
#           {'@sequence': '3',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'P'},
#            'main-group': {'$': '29'},
#            'subgroup': {'$': '02'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'EP'}}],
#          'combination-set': [{'@sequence': '1',
#            'group-number': {'$': '1'},
#            'combination-rank': [{'rank-number': {'$': '1'},
#              'patent-classification': {'classification-scheme': {'@office': 'EP',
#                '@scheme': 'CPCI'},
#               'classification-symbol': {'$': 'A61K31/565'},
#               'classification-value': {'$': 'I'},
#               'generating-office': {'$': 'EP'}}},
#             {'rank-number': {'$': '2'},
#              'patent-classification': {'classification-scheme': {'@office': 'EP',
#                '@scheme': 'CPCI'},
#               'classification-symbol': {'$': 'A61K2300/00'},
#               'classification-value': {'$': 'I'},
#               'generating-office': {'$': 'EP'}}}]},
#           {'@sequence': '2',
#            'group-number': {'$': '2'},
#            'combination-rank': [{'rank-number': {'$': '1'},
#              'patent-classification': {'classification-scheme': {'@office': 'EP',
#                '@scheme': 'CPCI'},
#               'classification-symbol': {'$': 'A61K31/585'},
#               'classification-value': {'$': 'I'},
#               'generating-office': {'$': 'EP'}}},
#             {'rank-number': {'$': '2'},
#              'patent-classification': {'classification-scheme': {'@office': 'EP',
#                '@scheme': 'CPCI'},
#               'classification-symbol': {'$': 'A61K2300/00'},
#               'classification-value': {'$': 'I'},
#               'generating-office': {'$': 'EP'}}}]}]},
#         'application-reference': {'@doc-id': '617554702',
#          'document-id': [{'@document-id-type': 'docdb',
#            'country': {'$': 'JP'},
#            'doc-number': {'$': '2024021608'},
#            'kind': {'$': 'A'}},
#           {'@document-id-type': 'epodoc',
#            'doc-number': {'$': 'JP20240021608'},
#            'date': {'$': '20240216'}},
#           {'@document-id-type': 'original',
#            'doc-number': {'$': '2024021608'}}]},
#         'priority-claims': {'priority-claim': [{'@sequence': '1',
#            '@kind': 'regional',
#            'document-id': [{'@document-id-type': 'epodoc',
#              'doc-number': {'$': 'EP20230158334'},
#              'date': {'$': '20230223'}},
#             {'@document-id-type': 'original',
#              'doc-number': {'$': '23158334'}}]},
#           {'@sequence': '2',
#            '@kind': 'regional',
#            'document-id': [{'@document-id-type': 'epodoc',
#              'doc-number': {'$': 'EP20230194864'},
#              'date': {'$': '20230901'}},
#             {'@document-id-type': 'original',
#              'doc-number': {'$': '23194864'}}]}]},
#         'parties': {'applicants': {'applicant': {'@sequence': '1',
#            '@data-format': 'original',
#            'applicant-name': {'name': {'$': 'エステトラ  ソシエタ  ア  レスポンサビリタ  リミタータ'}}}},
#          'inventors': {'inventor': [{'@sequence': '1',
#             '@data-format': 'original',
#             'inventor-name': {'name': {'$': '平山  正史,'}}},
#            {'@sequence': '2',
#             '@data-format': 'original',
#             'inventor-name': {'name': {'$': '野上  正義'}}}]}},
#         'invention-title': {'$': '子宮内膜症に関連する疼痛を治療するための組成物', '@lang': 'ol'}},
#        'abstract': {'@lang': 'ol',
#         'p': {'$': '【課題】 子宮内膜症に関連する疼痛を治療するための組成物を提供する。【解決手段】 本発明は、被験者において子宮内膜症と関連する疼痛を緩和するのに使用するためのエステトロール及びドロスピレノンを含む医薬組成物に関する。本明細書において記載されている医薬組成物は、特に、ビジュアルアナログスケール（ＶＡＳ）スコアによって測定されるものなどの高い程度、頻度及び／若しくは強度の疼痛を報告する並びに／又は腺筋症若しくは子宮筋腫などのさらなる合併症を有する被験者において子宮内膜症と関連する疼痛を緩和することにおいて有効である。上記及び対応する治療の方法に関する使用もまた、本明細書において記載される。【選択図】 無し'}}}},
#      {'exchange-document': {'@system': 'ops.epo.org',
#        '@family-id': '85201060',
#        '@country': 'JP',
#        '@doc-number': '2024532015',
#        '@kind': 'A',
#        'bibliographic-data': {'publication-reference': {'document-id': [{'@document-id-type': 'docdb',
#            'country': {'$': 'JP'},
#            'doc-number': {'$': '2024532015'},
#            'kind': {'$': 'A'},
#            'date': {'$': '20240904'}},
#           {'@document-id-type': 'epodoc',
#            'doc-number': {'$': 'JP2024532015'},
#            'date': {'$': '20240904'}}]},
#         'classifications-ipcr': {'classification-ipcr': [{'@sequence': '1',
#            'text': {'$': 'A61K   9/    14            A I'}},
#           {'@sequence': '2', 'text': {'$': 'A61K   9/    50            A I'}},
#           {'@sequence': '3', 'text': {'$': 'A61K   9/    51            A I'}},
#           {'@sequence': '4', 'text': {'$': 'A61K  31/  4025            A I'}},
#           {'@sequence': '5', 'text': {'$': 'A61K  47/    34            A I'}},
#           {'@sequence': '6', 'text': {'$': 'A61K  47/    36            A I'}},
#           {'@sequence': '7', 'text': {'$': 'A61K  47/    42            A I'}},
#           {'@sequence': '8', 'text': {'$': 'A61P   9/    00            A I'}},
#           {'@sequence': '9', 'text': {'$': 'A61P   9/    12            A I'}},
#           {'@sequence': '10', 'text': {'$': 'A61P  11/    00            A I'}},
#           {'@sequence': '11', 'text': {'$': 'A61P  15/    00            A I'}},
#           {'@sequence': '12', 'text': {'$': 'A61P  15/    10            A I'}},
#           {'@sequence': '13', 'text': {'$': 'A61P  27/    02            A I'}},
#           {'@sequence': '14', 'text': {'$': 'A61P  29/    00            A I'}},
#           {'@sequence': '15',
#            'text': {'$': 'A61P  35/    00            A I'}}]},
#         'patent-classifications': {'patent-classification': [{'@sequence': '1',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '9'},
#            'subgroup': {'$': '0002'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'KR'}},
#           {'@sequence': '2',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '9'},
#            'subgroup': {'$': '14'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'KR'}},
#           {'@sequence': '3',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '9'},
#            'subgroup': {'$': '1641'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'KR'}},
#           {'@sequence': '4',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '9'},
#            'subgroup': {'$': '20'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'KR'}},
#           {'@sequence': '5',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '31'},
#            'subgroup': {'$': '4025'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'KR'}},
#           {'@sequence': '6',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '31'},
#            'subgroup': {'$': '4025'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'US'}},
#           {'@sequence': '7',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '31'},
#            'subgroup': {'$': '4025'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'EP'}},
#           {'@sequence': '8',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '47'},
#            'subgroup': {'$': '50'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'US'}},
#           {'@sequence': '9',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'P'},
#            'main-group': {'$': '9'},
#            'subgroup': {'$': '10'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'KR'}},
#           {'@sequence': '10',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'P'},
#            'main-group': {'$': '9'},
#            'subgroup': {'$': '10'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'EP'}}]},
#         'application-reference': {'@doc-id': '617554684',
#          'document-id': [{'@document-id-type': 'docdb',
#            'country': {'$': 'JP'},
#            'doc-number': {'$': '2024508325'},
#            'kind': {'$': 'A'}},
#           {'@document-id-type': 'epodoc',
#            'doc-number': {'$': 'JP20240508325'},
#            'date': {'$': '20220812'}},
#           {'@document-id-type': 'original',
#            'doc-number': {'$': '2024508325'}}]},
#         'priority-claims': {'priority-claim': [{'@sequence': '1',
#            '@kind': 'national',
#            'document-id': [{'@document-id-type': 'epodoc',
#              'doc-number': {'$': 'US202163232603P'},
#              'date': {'$': '20210812'}},
#             {'@document-id-type': 'original',
#              'doc-number': {'$': '63/232,603'}}]},
#           {'@sequence': '2',
#            '@kind': 'national',
#            'document-id': [{'@document-id-type': 'epodoc',
#              'doc-number': {'$': 'WO2022US40197'},
#              'date': {'$': '20220812'}},
#             {'@document-id-type': 'original',
#              'doc-number': {'$': 'US2022040197'}}]}]},
#         'parties': {'applicants': {'applicant': {'@sequence': '1',
#            '@data-format': 'original',
#            'applicant-name': {'name': {'$': 'クラリス  バイオ  インコーポレイテッド'}}}},
#          'inventors': {'inventor': [{'@sequence': '1',
#             '@data-format': 'original',
#             'inventor-name': {'name': {'$': 'トゥー  トゥレイン  エム．,'}}},
#            {'@sequence': '2',
#             '@data-format': 'original',
#             'inventor-name': {'name': {'$': 'ヴィロストコ  バーバラ  エム．,'}}},
#            {'@sequence': '3',
#             '@data-format': 'original',
#             'inventor-name': {'name': {'$': 'フォーシュ  マイケル  ピー．'}}}]}},
#         'invention-title': {'$': '徐放性クロマカリム療法用の組成物及び方法', '@lang': 'ol'}},
#        'abstract': {'@lang': 'ol',
#         'p': {'$': '送達を必要とする患者へのｉｎ ｖｉｖｏでの送達に有利な特性を有する式Ｉ、式ＩＩ、若しくは式ＩＩＩ、又はそれらの薬学的に許容可能な塩の生分解性のマイクロ粒子、ナノ粒子、又は他のポリマー製剤を含む徐放性医薬組成物が提供される。上記徐放性製剤は、レブクロマカリムを含むクロマカリムの送達における旧来からの障害を克服する。'}}}},
#      {'exchange-document': {'@system': 'ops.epo.org',
#        '@family-id': '83004729',
#        '@country': 'JP',
#        '@doc-number': '2024532010',
#        '@kind': 'A',
#        'bibliographic-data': {'publication-reference': {'document-id': [{'@document-id-type': 'docdb',
#            'country': {'$': 'JP'},
#            'doc-number': {'$': '2024532010'},
#            'kind': {'$': 'A'},
#            'date': {'$': '20240904'}},
#           {'@document-id-type': 'epodoc',
#            'doc-number': {'$': 'JP2024532010'},
#            'date': {'$': '20240904'}}]},
#         'classifications-ipcr': {'classification-ipcr': [{'@sequence': '1',
#            'text': {'$': 'A61K  35/    17            A I'}},
#           {'@sequence': '2', 'text': {'$': 'A61P  35/    00            A I'}},
#           {'@sequence': '3', 'text': {'$': 'G01N  33/    53            A I'}},
#           {'@sequence': '4',
#            'text': {'$': 'G01N  33/    68            A I'}}]},
#         'patent-classifications': {'patent-classification': [{'@sequence': '1',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '39'},
#            'subgroup': {'$': '001112'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'IL'}},
#           {'@sequence': '2',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '39'},
#            'subgroup': {'$': '001112'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'US'}},
#           {'@sequence': '3',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '39'},
#            'subgroup': {'$': '001112'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'EP'}},
#           {'@sequence': '4',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '45'},
#            'subgroup': {'$': '00'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'KR'}},
#           {'@sequence': '5',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'P'},
#            'main-group': {'$': '35'},
#            'subgroup': {'$': '00'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'IL'}},
#           {'@sequence': '6',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'P'},
#            'main-group': {'$': '35'},
#            'subgroup': {'$': '00'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'EP'}},
#           {'@sequence': '7',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'P'},
#            'main-group': {'$': '39'},
#            'subgroup': {'$': '00'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'KR'}},
#           {'@sequence': '8',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'P'},
#            'main-group': {'$': '43'},
#            'subgroup': {'$': '00'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'KR'}},
#           {'@sequence': '9',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '01'},
#            'subclass': {'$': 'N'},
#            'main-group': {'$': '33'},
#            'subgroup': {'$': '5014'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'IL'}},
#           {'@sequence': '10',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '01'},
#            'subclass': {'$': 'N'},
#            'main-group': {'$': '33'},
#            'subgroup': {'$': '5014'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'KR'}},
#           {'@sequence': '11',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '01'},
#            'subclass': {'$': 'N'},
#            'main-group': {'$': '33'},
#            'subgroup': {'$': '5014'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'EP'}},
#           {'@sequence': '12',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '01'},
#            'subclass': {'$': 'N'},
#            'main-group': {'$': '33'},
#            'subgroup': {'$': '57426'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'IL'}},
#           {'@sequence': '13',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '01'},
#            'subclass': {'$': 'N'},
#            'main-group': {'$': '33'},
#            'subgroup': {'$': '57426'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'KR'}},
#           {'@sequence': '14',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '01'},
#            'subclass': {'$': 'N'},
#            'main-group': {'$': '33'},
#            'subgroup': {'$': '57426'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'EP'}},
#           {'@sequence': '15',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '16'},
#            'subclass': {'$': 'B'},
#            'main-group': {'$': '5'},
#            'subgroup': {'$': '20'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'US'}},
#           {'@sequence': '16',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '16'},
#            'subclass': {'$': 'B'},
#            'main-group': {'$': '5'},
#            'subgroup': {'$': '20'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'IL'}},
#           {'@sequence': '17',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '16'},
#            'subclass': {'$': 'B'},
#            'main-group': {'$': '40'},
#            'subgroup': {'$': '00'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'US'}},
#           {'@sequence': '18',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '16'},
#            'subclass': {'$': 'B'},
#            'main-group': {'$': '40'},
#            'subgroup': {'$': '00'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'IL'}},
#           {'@sequence': '19',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '16'},
#            'subclass': {'$': 'H'},
#            'main-group': {'$': '20'},
#            'subgroup': {'$': '17'},
#            'classification-value': {'$': 'I'},
#            'generating-office': {'$': 'KR'}},
#           {'@sequence': '20',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '39'},
#            'subgroup': {'$': '464412'},
#            'classification-value': {'$': 'A'},
#            'generating-office': {'$': 'KR'}},
#           {'@sequence': '21',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '2039'},
#            'subgroup': {'$': '5156'},
#            'classification-value': {'$': 'A'},
#            'generating-office': {'$': 'IL'}},
#           {'@sequence': '22',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '2039'},
#            'subgroup': {'$': '5156'},
#            'classification-value': {'$': 'A'},
#            'generating-office': {'$': 'US'}},
#           {'@sequence': '23',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'A'},
#            'class': {'$': '61'},
#            'subclass': {'$': 'K'},
#            'main-group': {'$': '2039'},
#            'subgroup': {'$': '5156'},
#            'classification-value': {'$': 'A'},
#            'generating-office': {'$': 'EP'}},
#           {'@sequence': '24',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '01'},
#            'subclass': {'$': 'N'},
#            'main-group': {'$': '2333'},
#            'subgroup': {'$': '5443'},
#            'classification-value': {'$': 'A'},
#            'generating-office': {'$': 'IL'}},
#           {'@sequence': '25',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '01'},
#            'subclass': {'$': 'N'},
#            'main-group': {'$': '2333'},
#            'subgroup': {'$': '5443'},
#            'classification-value': {'$': 'A'},
#            'generating-office': {'$': 'KR'}},
#           {'@sequence': '26',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '01'},
#            'subclass': {'$': 'N'},
#            'main-group': {'$': '2333'},
#            'subgroup': {'$': '5443'},
#            'classification-value': {'$': 'A'},
#            'generating-office': {'$': 'EP'}},
#           {'@sequence': '27',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '01'},
#            'subclass': {'$': 'N'},
#            'main-group': {'$': '2800'},
#            'subgroup': {'$': '52'},
#            'classification-value': {'$': 'A'},
#            'generating-office': {'$': 'IL'}},
#           {'@sequence': '28',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '01'},
#            'subclass': {'$': 'N'},
#            'main-group': {'$': '2800'},
#            'subgroup': {'$': '52'},
#            'classification-value': {'$': 'A'},
#            'generating-office': {'$': 'KR'}},
#           {'@sequence': '29',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '01'},
#            'subclass': {'$': 'N'},
#            'main-group': {'$': '2800'},
#            'subgroup': {'$': '52'},
#            'classification-value': {'$': 'A'},
#            'generating-office': {'$': 'EP'}},
#           {'@sequence': '30',
#            'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#            'section': {'$': 'G'},
#            'class': {'$': '16'},
#            'subclass': {'$': 'B'},
#            'main-group': {'$': '40'},
#            'subgroup': {'$': '00'},
#            'classification-value': {'$': 'A'},
#            'generating-office': {'$': 'KR'}}]},
#         'application-reference': {'@doc-id': '617554658',
#          'document-id': [{'@document-id-type': 'docdb',
#            'country': {'$': 'JP'},
#            'doc-number': {'$': '2024504967'},
#            'kind': {'$': 'A'}},
#           {'@document-id-type': 'epodoc',
#            'doc-number': {'$': 'JP20240504967'},
#            'date': {'$': '20220729'}},
#           {'@document-id-type': 'original',
#            'doc-number': {'$': '2024504967'}}]},
#         'priority-claims': {'priority-claim': [{'@sequence': '1',
#            '@kind': 'national',
#            'document-id': [{'@document-id-type': 'epodoc',
#              'doc-number': {'$': 'US202163227677P'},
#              'date': {'$': '20210730'}},
#             {'@document-id-type': 'original',
#              'doc-number': {'$': '63/227,677'}}]},
#           {'@sequence': '2',
#            '@kind': 'national',
#            'document-id': [{'@document-id-type': 'epodoc',
#              'doc-number': {'$': 'US202163279615P'},
#              'date': {'$': '20211115'}},
#             {'@document-id-type': 'original',
#              'doc-number': {'$': '63/279,615'}}]},
#           {'@sequence': '3',
#            '@kind': 'national',
#            'document-id': [{'@document-id-type': 'epodoc',
#              'doc-number': {'$': 'WO2022US74306'},
#              'date': {'$': '20220729'}},
#             {'@document-id-type': 'original',
#              'doc-number': {'$': 'US2022074306'}}]}]},
#         'parties': {'applicants': {'applicant': {'@sequence': '1',
#            '@data-format': 'original',
#            'applicant-name': {'name': {'$': 'カイト  ファーマ  インコーポレイテッド'}}}},
#          'inventors': {'inventor': {'@sequence': '1',
#            '@data-format': 'original',
#            'inventor-name': {'name': {'$': 'ソン  チンホワ'}}}}},
#         'invention-title': {'$': '細胞療法により誘発された毒性の監視及び管理', '@lang': 'ol'}},
#        'abstract': {'@lang': 'ol',
#         'p': {'$': '本開示は、概して、細胞療法患者が細胞療法後に毒性を経験する可能性が高いか又はそうではないと同定するための組成物及び方法に関する。方法は、患者における血清ＩＬ－１５及びＭＣＰ－１レベルなどの治療前共変量、又は投与されている細胞の生存率を使用して、そのような毒性の発症の可能性を予測することができるという発見に基づく。患者が毒性を経験する可能性が高いか又はそうではないと同定されると、毒性を監視及び管理するための組成物及び方法も提供される。'}}}}]}}}}

# %%
docs = data['ops:world-patent-data']['ops:biblio-search'][ 'ops:search-result']['exchange-documents']
[
    {
        'family' : doc['exchange-document']['@family-id'],
        'publication_number' : doc['exchange-document']['bibliographic-data']['publication-reference']['document-id'][0]['doc-number']['$'],
        'application_number' : doc['exchange-document']['bibliographic-data']['application-reference']['document-id'][0]['doc-number']['$']
    } for doc in docs
]
# Out:
# [{'family': '89897625',
#   'publication_number': '2024120161',
#   'application_number': '2024021608'},
#  {'family': '85201060',
#   'publication_number': '2024532015',
#   'application_number': '2024508325'},
#  {'family': '83004729',
#   'publication_number': '2024532010',
#   'application_number': '2024504967'}]

# %%
docs[0]
# Out:
# {'exchange-document': {'@system': 'ops.epo.org',
#   '@family-id': '89897625',
#   '@country': 'JP',
#   '@doc-number': '2024120161',
#   '@kind': 'A',
#   'bibliographic-data': {'publication-reference': {'document-id': [{'@document-id-type': 'docdb',
#       'country': {'$': 'JP'},
#       'doc-number': {'$': '2024120161'},
#       'kind': {'$': 'A'},
#       'date': {'$': '20240904'}},
#      {'@document-id-type': 'epodoc',
#       'doc-number': {'$': 'JP2024120161'},
#       'date': {'$': '20240904'}}]},
#    'classifications-ipcr': {'classification-ipcr': [{'@sequence': '1',
#       'text': {'$': 'A61K  31/   565            A I'}},
#      {'@sequence': '2', 'text': {'$': 'A61K  31/   585            A I'}},
#      {'@sequence': '3', 'text': {'$': 'A61P   5/    30            A I'}},
#      {'@sequence': '4', 'text': {'$': 'A61P   5/    34            A I'}},
#      {'@sequence': '5', 'text': {'$': 'A61P  43/    00            A I'}}]},
#    'patent-classifications': {'patent-classification': [{'@sequence': '1',
#       'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#       'section': {'$': 'A'},
#       'class': {'$': '61'},
#       'subclass': {'$': 'K'},
#       'main-group': {'$': '31'},
#       'subgroup': {'$': '565'},
#       'classification-value': {'$': 'I'},
#       'generating-office': {'$': 'EP'}},
#      {'@sequence': '2',
#       'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#       'section': {'$': 'A'},
#       'class': {'$': '61'},
#       'subclass': {'$': 'K'},
#       'main-group': {'$': '31'},
#       'subgroup': {'$': '585'},
#       'classification-value': {'$': 'I'},
#       'generating-office': {'$': 'EP'}},
#      {'@sequence': '3',
#       'classification-scheme': {'@office': 'EP', '@scheme': 'CPCI'},
#       'section': {'$': 'A'},
#       'class': {'$': '61'},
#       'subclass': {'$': 'P'},
#       'main-group': {'$': '29'},
#       'subgroup': {'$': '02'},
#       'classification-value': {'$': 'I'},
#       'generating-office': {'$': 'EP'}}],
#     'combination-set': [{'@sequence': '1',
#       'group-number': {'$': '1'},
#       'combination-rank': [{'rank-number': {'$': '1'},
#         'patent-classification': {'classification-scheme': {'@office': 'EP',
#           '@scheme': 'CPCI'},
#          'classification-symbol': {'$': 'A61K31/565'},
#          'classification-value': {'$': 'I'},
#          'generating-office': {'$': 'EP'}}},
#        {'rank-number': {'$': '2'},
#         'patent-classification': {'classification-scheme': {'@office': 'EP',
#           '@scheme': 'CPCI'},
#          'classification-symbol': {'$': 'A61K2300/00'},
#          'classification-value': {'$': 'I'},
#          'generating-office': {'$': 'EP'}}}]},
#      {'@sequence': '2',
#       'group-number': {'$': '2'},
#       'combination-rank': [{'rank-number': {'$': '1'},
#         'patent-classification': {'classification-scheme': {'@office': 'EP',
#           '@scheme': 'CPCI'},
#          'classification-symbol': {'$': 'A61K31/585'},
#          'classification-value': {'$': 'I'},
#          'generating-office': {'$': 'EP'}}},
#        {'rank-number': {'$': '2'},
#         'patent-classification': {'classification-scheme': {'@office': 'EP',
#           '@scheme': 'CPCI'},
#          'classification-symbol': {'$': 'A61K2300/00'},
#          'classification-value': {'$': 'I'},
#          'generating-office': {'$': 'EP'}}}]}]},
#    'application-reference': {'@doc-id': '617554702',
#     'document-id': [{'@document-id-type': 'docdb',
#       'country': {'$': 'JP'},
#       'doc-number': {'$': '2024021608'},
#       'kind': {'$': 'A'}},
#      {'@document-id-type': 'epodoc',
#       'doc-number': {'$': 'JP20240021608'},
#       'date': {'$': '20240216'}},
#      {'@document-id-type': 'original', 'doc-number': {'$': '2024021608'}}]},
#    'priority-claims': {'priority-claim': [{'@sequence': '1',
#       '@kind': 'regional',
#       'document-id': [{'@document-id-type': 'epodoc',
#         'doc-number': {'$': 'EP20230158334'},
#         'date': {'$': '20230223'}},
#        {'@document-id-type': 'original', 'doc-number': {'$': '23158334'}}]},
#      {'@sequence': '2',
#       '@kind': 'regional',
#       'document-id': [{'@document-id-type': 'epodoc',
#         'doc-number': {'$': 'EP20230194864'},
#         'date': {'$': '20230901'}},
#        {'@document-id-type': 'original', 'doc-number': {'$': '23194864'}}]}]},
#    'parties': {'applicants': {'applicant': {'@sequence': '1',
#       '@data-format': 'original',
#       'applicant-name': {'name': {'$': 'エステトラ  ソシエタ  ア  レスポンサビリタ  リミタータ'}}}},
#     'inventors': {'inventor': [{'@sequence': '1',
#        '@data-format': 'original',
#        'inventor-name': {'name': {'$': '平山  正史,'}}},
#       {'@sequence': '2',
#        '@data-format': 'original',
#        'inventor-name': {'name': {'$': '野上  正義'}}}]}},
#    'invention-title': {'$': '子宮内膜症に関連する疼痛を治療するための組成物', '@lang': 'ol'}},
#   'abstract': {'@lang': 'ol',
#    'p': {'$': '【課題】 子宮内膜症に関連する疼痛を治療するための組成物を提供する。【解決手段】 本発明は、被験者において子宮内膜症と関連する疼痛を緩和するのに使用するためのエステトロール及びドロスピレノンを含む医薬組成物に関する。本明細書において記載されている医薬組成物は、特に、ビジュアルアナログスケール（ＶＡＳ）スコアによって測定されるものなどの高い程度、頻度及び／若しくは強度の疼痛を報告する並びに／又は腺筋症若しくは子宮筋腫などのさらなる合併症を有する被験者において子宮内膜症と関連する疼痛を緩和することにおいて有効である。上記及び対応する治療の方法に関する使用もまた、本明細書において記載される。【選択図】 無し'}}}}

# %% [markdown]
# #### Loop to retrieve all files

# %%
start = 1
doc_list = []
while True:

    end = start + batch_size - 1
    data = get_patent_data(query_cql, start, end)
    if not data:
        break
    docs = data['ops:world-patent-data']['ops:biblio-search'][ 'ops:search-result']['exchange-documents']
    doc_list = doc_list + [
            {
            'family' : doc['exchange-document']['@family-id'],
            'publication_number' : doc['exchange-document']['bibliographic-data']['publication-reference']['document-id'][0]['doc-number']['$'],
            'application_number' : doc['exchange-document']['bibliographic-data']['application-reference']['document-id'][0]['doc-number']['$']
            } for doc in docs
    ]
    time.sleep(3) # wait few seconds not to get blocked
    start = end
# Out:
# Error: 400 - <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <fault xmlns="http://ops.epo.org">
#     <code>CLIENT.InvalidQuery</code>
#     <message>The request was invalid</message>
# </fault>

# %%
len(doc_list)
# Out:
# 2000

# %%
end
# Out:
# 2080

# %%
pd.DataFrame(doc_list).drop_duplicates(ignore_index=True).shape
# Out:
# (1981, 3)

# %%
df = pd.DataFrame(doc_list).drop_duplicates(ignore_index=True)
df.to_csv('Patents_publication_numbers.csv', index=False)

files.download('Patents_publication_numbers.csv') #Download from Google Colab

# %% [markdown]
# Para sacar los datos hicimos este paso para todas las IPC que se nos dieron en un principio:<br>
# C07D, A61P, A61K, C07B, C07C, C07K, C07F, C07H, C12N, G01N, B12N (biosimilars), for industry comparison: telecommunication (Apple, Samsung): G06F, H04W, H01L <br>
#
# Depues exportamos cada uno y los juntamos todos a mano.
